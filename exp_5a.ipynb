# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv(r"C:\Users\Iniya\Downloads\Retail_Sales_Raw .csv")
df["OrderDate"] = pd.to_datetime(df["OrderDate"], dayfirst=False, errors="coerce")
df["Sales"] = df["Quantity"] * df["UnitPrice"] * (1 - df["Discount"].fillna(0))
monthly_sales = df.groupby(df["OrderDate"].dt.strftime("%B"))["Sales"].sum()
months = monthly_sales.index
sales = monthly_sales.values

# %%
# Line Chart
plt.plot(months, sales, marker="o")
plt.title("Monthly Sales")
plt.xlabel("Months")
plt.ylabel("Sales")
plt.xticks(rotation=45)
plt.show()

# %%
# Bar Chart
plt.bar(months, sales)
plt.title("Monthly Sales")
plt.xlabel("Months")
plt.ylabel("Sales")
plt.xticks(rotation=45)
plt.show()

# %%
# Pie Chart
plt.pie(sales, labels=months, autopct="%1.1f%%")
plt.title("Sales Distribution")
plt.show()

# %%
# Histogram
plt.hist(df["Sales"].dropna(), bins=5)
plt.title("Sales Distribution")
plt.xlabel("Sales")
plt.ylabel("Frequency")
plt.show()

# %%
# Scatter Plot
plt.scatter(df["Quantity"], df["Sales"])
plt.title("Quantity vs Sales")
plt.xlabel("Quantity")
plt.ylabel("Sales")
plt.show()

# %%
# Box Plot
plt.boxplot(df["Sales"].dropna())
plt.title("Sales Box Plot")
plt.ylabel("Sales")
plt.show()
