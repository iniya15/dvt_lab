# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df = pd.read_csv(r"C:\Users\Iniya\Downloads\student.csv")
print(df)
print(df.head())
print(df.shape)
print(df.dtypes)
print(df.describe())
print(df[df["Marks"] > 80])
print(df[df["Attendance"] > 90])
print(df.sort_values("Marks", ascending=False))
print(df.sort_values("Attendance", ascending=False))
print(df.groupby("Dept")["Marks"].mean())
print(df.groupby("Dept")["Attendance"].mean())
print("Mean Marks:", df["Marks"].mean())
print("Median Marks:", df["Marks"].median())
print("Minimum Marks:", df["Marks"].min())
print("Maximum Marks:", df["Marks"].max())
print("Standard Deviation:", df["Marks"].std())
print(df[["Marks", "Attendance"]].corr())
print("Correlation:", df["Marks"].corr(df["Attendance"]))
plt.bar(df["Name"], df["Marks"])
plt.title("Student Marks")
plt.xlabel("Name")
plt.ylabel("Marks")
plt.show()
plt.plot(df["Name"], df["Attendance"], marker="o")
plt.title("Student Attendance")
plt.xlabel("Name")
plt.ylabel("Attendance")
plt.show()
plt.scatter(df["Attendance"], df["Marks"])
plt.title("Marks vs Attendance")
plt.xlabel("Attendance")
plt.ylabel("Marks")
plt.show()
plt.hist(df["Marks"], bins=5)
plt.title("Marks Distribution")
plt.xlabel("Marks")
plt.ylabel("Number of Students")
plt.show()
plt.boxplot(df["Marks"])
plt.title("Marks Box Plot")
plt.ylabel("Marks")
plt.show()
# Out:
#    Unnamed: 0  Roll No     Name   Dept  Marks  Attendance
# 0           0      101     Arun    CSE     85          92
# 1           1      102     Bala     IT     78          88
# 2           2      103    Divya    CSE     95          96
# 3           3      104    Priya  AI&DS     90          94
# 4           4      105     Ravi     IT     72          85
# 5           5      106  Karthik  AI&DS     88          91
#    Unnamed: 0  Roll No   Name   Dept  Marks  Attendance
# 0           0      101   Arun    CSE     85          92
# 1           1      102   Bala     IT     78          88
# 2           2      103  Divya    CSE     95          96
# 3           3      104  Priya  AI&DS     90          94
# 4           4      105   Ravi     IT     72          85
# (6, 6)
# Unnamed: 0    int64
# Roll No       int64
# Name            str
# Dept            str
# Marks         int64
# Attendance    int64
# dtype: object
#        Unnamed: 0     Roll No      Marks  Attendance
# count    6.000000    6.000000   6.000000        6.00
# mean     2.500000  103.500000  84.666667       91.00
# std      1.870829    1.870829   8.382521        4.00
# min      0.000000  101.000000  72.000000       85.00
# 25%      1.250000  102.250000  79.750000       88.75
# 50%      2.500000  103.500000  86.500000       91.50
# 75%      3.750000  104.750000  89.500000       93.50
# max      5.000000  106.000000  95.000000       96.00
#    Unnamed: 0  Roll No     Name   Dept  Marks  Attendance
# 0           0      101     Arun    CSE     85          92
# 2           2      103    Divya    CSE     95          96
# 3           3      104    Priya  AI&DS     90          94
# 5           5      106  Karthik  AI&DS     88          91
#    Unnamed: 0  Roll No     Name   Dept  Marks  Attendance
# 0           0      101     Arun    CSE     85          92
# 2           2      103    Divya    CSE     95          96
# 3           3      104    Priya  AI&DS     90          94
# 5           5      106  Karthik  AI&DS     88          91
#    Unnamed: 0  Roll No     Name   Dept  Marks  Attendance
# 2           2      103    Divya    CSE     95          96
# 3           3      104    Priya  AI&DS     90          94
# 5           5      106  Karthik  AI&DS     88          91
# 0           0      101     Arun    CSE     85          92
# 1           1      102     Bala     IT     78          88
# 4           4      105     Ravi     IT     72          85
#    Unnamed: 0  Roll No     Name   Dept  Marks  Attendance
# 2           2      103    Divya    CSE     95          96
# 3           3      104    Priya  AI&DS     90          94
# 0           0      101     Arun    CSE     85          92
# 5           5      106  Karthik  AI&DS     88          91
# 1           1      102     Bala     IT     78          88
# 4           4      105     Ravi     IT     72          85
# Dept
# AI&DS    89.0
# CSE      90.0
# IT       75.0
# Name: Marks, dtype: float64
# Dept
# AI&DS    92.5
# CSE      94.0
# IT       86.5
# Name: Attendance, dtype: float64
# Mean Marks: 84.66666666666667
# Median Marks: 86.5
# Minimum Marks: 72
# Maximum Marks: 95
# Standard Deviation: 8.382521498133285
#                Marks  Attendance
# Marks       1.000000    0.978226
# Attendance  0.978226    1.000000
# Correlation: 0.9782259433305447
